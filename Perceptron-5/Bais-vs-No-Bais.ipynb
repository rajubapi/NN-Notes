# %% [markdown]
# # Bias vs No Bais
#
# A bias term simply allows for translation of the decision boundary that the perceptron algorith learns. When a bias term is not included, the decision boundary has to pass through the origin, called the homogenous solution. A bais term in the equation will shift the decision boundary away from the origin resulting in an non-homogenous solution.

# %% [markdown]
# Consider the following data set
#
# ## Unbaised Neuron

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
from Figures import figure1
figure1.drawData()

# %% [markdown]
# Let us try leaning a decision boundary that does not include the bais term. The boundary must pass through the origin and is called an homogenous solution.

# %%
figure1.drawNoBais()

# %% [markdown]
# As you can observe the algorithm fails to classify an entire dataset. No matter, what orientation the decision boundary is, we can fing no boundary that seperates the data set and passes through the origin.

# %% [markdown]
# ## Biased Neuron

# %%
# %autoreload 2
from Figures import figure2
figure2.drawBais()

# %% [markdown]
# We now are able to classify the linearly separable dataset perfectly as we should be.
